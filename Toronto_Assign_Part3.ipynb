# %% [markdown]
# # Part 1:

# %% [markdown]
# ## 1- Importing the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2- Reading the HTML table from the Wikipedia website to a pandas dataframe

# %%
url_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
column_names = ['PostalCode', 'Borough', 'Neighborhood'] 

# Initiating the dataframe
postal_code_df = pd.DataFrame(columns=column_names)

# Reading the HTML table from wikipedia website
postal_data = pd.read_html(url_wiki)

# %% [markdown]
# ## 3- Creating the dataframe

# %%
# Ignoring the rows with "Not assigned" values
postal_data[0]=postal_data[0][~postal_data[0]['Borough'].isin(['Not assigned'])]
postal_code_df = postal_data[0]

#Grouping the dataframe according to the instructions
postal_code_df = postal_code_df.groupby(['Postcode', 'Borough'], sort=False).agg( ','.join)
postal_code_df = postal_code_df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(list)
postal_code_df = postal_code_df.sample(frac=1).reset_index()
postal_code_df['Neighbourhood']= postal_code_df['Neighbourhood'].str.join(', ')
postal_code_df
# Out:
#     Postcode           Borough  \
# 0        M8W         Etobicoke
# 1        M5W  Downtown Toronto
# 2        M3J        North York
# 3        M4C         East York
# 4        M3N        North York
# 5        M4K      East Toronto
# 6        M5X  Downtown Toronto
# 7        M4A        North York
# 8        M2P        North York
# 9        M5J  Downtown Toronto
# 10       M2M        North York
# 11       M5A  Downtown Toronto
# 12       M6E              York
# 13       M1W       Scarborough
# 14       M1S       Scarborough
# 15       M4N   Central Toronto
# 16       M6C              York
# 17       M3B        North York
# 18       M6J      West Toronto
# 19       M1C       Scarborough
# 20       M7Y      East Toronto
# 21       M5C  Downtown Toronto
# 22       M5M        North York
# 23       M1X       Scarborough
# 24       M5B  Downtown Toronto
# 25       M1T       Scarborough
# 26       M8X         Etobicoke
# 27       M6K      West Toronto
# 28       M3H        North York
# 29       M4Y  Downtown Toronto
# ..       ...               ...
# 73       M5V  Downtown Toronto
# 74       M9L        North York
# 75       M4G         East York
# 76       M1L       Scarborough
# 77       M4E      East Toronto
# 78       M5S  Downtown Toronto
# 79       M4J         East York
# 80       M6N              York
# 81       M5H  Downtown Toronto
# 82       M1V       Scarborough
# 83       M6R      West Toronto
# 84       M3L        North York
# 85       M9N              York
# 86       M4V   Central Toronto
# 87       M6A        North York
# 88       M8V         Etobicoke
# 89       M9C         Etobicoke
# 90       M7R       Mississauga
# 91       M7A  Downtown Toronto
# 92       M9R         Etobicoke
# 93       M9P         Etobicoke
# 94       M6L        North York
# 95       M4T   Central Toronto
# 96       M3K        North York
# 97       M1K       Scarborough
# 98       M1P       Scarborough
# 99       M6B        North York
# 100      M4H         East York
# 101      M1E       Scarborough
# 102      M6M              York
#
#                                          Neighbourhood
# 0                                Alderwood,Long Branch
# 1                      Stn A PO Boxes 25 The Esplanade
# 2                       Northwood Park,York University
# 3                                     Woodbine Heights
# 4                                  Downsview Northwest
# 5                          The Danforth West,Riverdale
# 6                First Canadian Place,Underground city
# 7                                     Victoria Village
# 8                                      York Mills West
# 9      Harbourfront East,Toronto Islands,Union Station
# 10                              Newtonbrook,Willowdale
# 11                                        Harbourfront
# 12                                 Caledonia-Fairbanks
# 13                                     L'Amoreaux West
# 14                                           Agincourt
# 15                                       Lawrence Park
# 16                                  Humewood-Cedarvale
# 17                                     Don Mills North
# 18                             Little Portugal,Trinity
# 19                Highland Creek,Rouge Hill,Port Union
# 20   Business Reply Mail Processing Centre 969 Eastern
# 21                                      St. James Town
# 22                    Bedford Park,Lawrence Manor East
# 23                                         Upper Rouge
# 24                             Ryerson,Garden District
# 25               Clarks Corners,Sullivan,Tam O'Shanter
# 26         The Kingsway,Montgomery Road,Old Mill North
# 27          Brockton,Exhibition Place,Parkdale Village
# 28       Bathurst Manor,Downsview North,Wilson Heights
# 29                                Church and Wellesley
# ..                                                 ...
# 73   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 74                                       Humber Summit
# 75                                             Leaside
# 76                       Clairlea,Golden Mile,Oakridge
# 77                                         The Beaches
# 78                       Harbord,University of Toronto
# 79                                        East Toronto
# 80                        The Junction North,Runnymede
# 81                              Adelaide,King,Richmond
# 82   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 83                               Parkdale,Roncesvalles
# 84                                      Downsview West
# 85                                              Weston
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 87                     Lawrence Heights,Lawrence Manor
# 88          Humber Bay Shores,Mimico South,New Toronto
# 89   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 90               Canada Post Gateway Processing Centre
# 91                                        Queen's Park
# 92   Kingsview Village,Martin Grove Gardens,Richvie...
# 93                                           Westmount
# 94                    Downsview,North Park,Upwood Park
# 95                          Moore Park,Summerhill East
# 96                          CFB Toronto,Downsview East
# 97           East Birchmount Park,Ionview,Kennedy Park
# 98   Dorset Park,Scarborough Town Centre,Wexford He...
# 99                                           Glencairn
# 100                                   Thorncliffe Park
# 101                    Guildwood,Morningside,West Hill
# 102        Del Ray,Keelesdale,Mount Dennis,Silverthorn
#
# [103 rows x 3 columns]

# %% [markdown]
# ## 4- printing the size of the dataframe

# %%
postal_code_df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2:

# %% [markdown]
# ## 5- Reading the Geospatial data csv file:

# %%
postal_new_df = pd.read_csv('http://cocl.us/Geospatial_data')
postal_new_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## 6- Creating the new dataframe

# %%
column_names = ['PostalCode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
Toronto_df = pd.DataFrame(columns=column_names)

# %%
Toronto_df=pd.merge(postal_code_df,postal_new_df,left_on='Postcode',right_on='Postal Code', left_index=False, right_index=False)
Toronto_df.drop('Postal Code', axis =1, inplace=True)
Toronto_df.rename(columns = {'Postcode':'PostalCode'}, inplace = True)

# %%
Toronto_df
# Out:
#     PostalCode           Borough  \
# 0          M6L        North York
# 1          M2N        North York
# 2          M5R   Central Toronto
# 3          M4H         East York
# 4          M6N              York
# 5          M5G  Downtown Toronto
# 6          M4E      East Toronto
# 7          M6H      West Toronto
# 8          M3H        North York
# 9          M9A         Etobicoke
# 10         M4N   Central Toronto
# 11         M4B         East York
# 12         M4A        North York
# 13         M3K        North York
# 14         M5W  Downtown Toronto
# 15         M8X         Etobicoke
# 16         M2L        North York
# 17         M4S   Central Toronto
# 18         M5K  Downtown Toronto
# 19         M5L  Downtown Toronto
# 20         M9L        North York
# 21         M1M       Scarborough
# 22         M4C         East York
# 23         M6E              York
# 24         M7Y      East Toronto
# 25         M4P   Central Toronto
# 26         M1R       Scarborough
# 27         M1X       Scarborough
# 28         M3J        North York
# 29         M5P   Central Toronto
# ..         ...               ...
# 73         M9V         Etobicoke
# 74         M2R        North York
# 75         M3L        North York
# 76         M5X  Downtown Toronto
# 77         M1G       Scarborough
# 78         M4X  Downtown Toronto
# 79         M1L       Scarborough
# 80         M8V         Etobicoke
# 81         M5C  Downtown Toronto
# 82         M8Z         Etobicoke
# 83         M1H       Scarborough
# 84         M4K      East Toronto
# 85         M3B        North York
# 86         M4V   Central Toronto
# 87         M9W         Etobicoke
# 88         M9R         Etobicoke
# 89         M4Y  Downtown Toronto
# 90         M5J  Downtown Toronto
# 91         M1T       Scarborough
# 92         M1J       Scarborough
# 93         M3M        North York
# 94         M4R   Central Toronto
# 95         M2M        North York
# 96         M6R      West Toronto
# 97         M5S  Downtown Toronto
# 98         M6C              York
# 99         M1K       Scarborough
# 100        M4J         East York
# 101        M9C         Etobicoke
# 102        M2J        North York
#
#                                          Neighbourhood   Latitude  Longitude
# 0                     Downsview,North Park,Upwood Park  43.713756 -79.490074
# 1                                     Willowdale South  43.770120 -79.408493
# 2                    The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 3                                     Thorncliffe Park  43.705369 -79.349372
# 4                         The Junction North,Runnymede  43.673185 -79.487262
# 5                                   Central Bay Street  43.657952 -79.387383
# 6                                          The Beaches  43.676357 -79.293031
# 7                          Dovercourt Village,Dufferin  43.669005 -79.442259
# 8        Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 9                                     Islington Avenue  43.667856 -79.532242
# 10                                       Lawrence Park  43.728020 -79.388790
# 11                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 12                                    Victoria Village  43.725882 -79.315572
# 13                          CFB Toronto,Downsview East  43.737473 -79.464763
# 14                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 15         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 16                             Silver Hills,York Mills  43.757490 -79.374714
# 17                                          Davisville  43.704324 -79.388790
# 18             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 19                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 20                                       Humber Summit  43.756303 -79.565963
# 21       Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 22                                    Woodbine Heights  43.695344 -79.318389
# 23                                 Caledonia-Fairbanks  43.689026 -79.453512
# 24   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 25                                    Davisville North  43.712751 -79.390197
# 26                                    Maryvale,Wexford  43.750072 -79.295849
# 27                                         Upper Rouge  43.836125 -79.205636
# 28                      Northwood Park,York University  43.767980 -79.487262
# 29                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# ..                                                 ...        ...        ...
# 73   Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 74                                     Willowdale West  43.782736 -79.442259
# 75                                      Downsview West  43.739015 -79.506944
# 76               First Canadian Place,Underground city  43.648429 -79.382280
# 77                                              Woburn  43.770992 -79.216917
# 78                          Cabbagetown,St. James Town  43.667967 -79.367675
# 79                       Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 80          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 81                                      St. James Town  43.651494 -79.375418
# 82   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 83                                           Cedarbrae  43.773136 -79.239476
# 84                         The Danforth West,Riverdale  43.679557 -79.352188
# 85                                     Don Mills North  43.745906 -79.352188
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 87                                           Northwest  43.706748 -79.594054
# 88   Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 89                                Church and Wellesley  43.665860 -79.383160
# 90     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 91               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 92                                 Scarborough Village  43.744734 -79.239476
# 93                                   Downsview Central  43.728496 -79.495697
# 94                                  North Toronto West  43.715383 -79.405678
# 95                              Newtonbrook,Willowdale  43.789053 -79.408493
# 96                               Parkdale,Roncesvalles  43.648960 -79.456325
# 97                       Harbord,University of Toronto  43.662696 -79.400049
# 98                                  Humewood-Cedarvale  43.693781 -79.428191
# 99           East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 100                                       East Toronto  43.685347 -79.338106
# 101  Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 102                         Fairview,Henry Farm,Oriole  43.778517 -79.346556
#
# [103 rows x 5 columns]

# %% [markdown]
# # Part 3:

# %% [markdown]
# ## 1- Generating the map:
# ### Installing folium

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ## Plotting the map

# %%
Toronto_map = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

for lat,lng,borough,neighbourhood in zip(Toronto_df['Latitude'],Toronto_df['Longitude'],Toronto_df['Borough'],Toronto_df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(Toronto_map)
Toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Clusetering neighborhoods using kmeans:

# %%
# Kmeans:
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.cm as cm
import matplotlib.colors as colors
k=5
Toronto_clust = Toronto_df.drop(['PostalCode','Borough','Neighbourhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(Toronto_clust)
kmeans.labels_
Toronto_df.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
Toronto_df
# Out:
#      Cluster Labels PostalCode           Borough  \
# 0                 1        M8W         Etobicoke
# 1                 0        M5W  Downtown Toronto
# 2                 4        M3J        North York
# 3                 3        M4C         East York
# 4                 1        M3N        North York
# 5                 3        M4K      East Toronto
# 6                 0        M5X  Downtown Toronto
# 7                 3        M4A        North York
# 8                 4        M2P        North York
# 9                 0        M5J  Downtown Toronto
# 10                4        M2M        North York
# 11                0        M5A  Downtown Toronto
# 12                0        M6E              York
# 13                2        M1W       Scarborough
# 14                2        M1S       Scarborough
# 15                4        M4N   Central Toronto
# 16                0        M6C              York
# 17                3        M3B        North York
# 18                0        M6J      West Toronto
# 19                2        M1C       Scarborough
# 20                3        M7Y      East Toronto
# 21                0        M5C  Downtown Toronto
# 22                4        M5M        North York
# 23                2        M1X       Scarborough
# 24                0        M5B  Downtown Toronto
# 25                2        M1T       Scarborough
# 26                1        M8X         Etobicoke
# 27                0        M6K      West Toronto
# 28                4        M3H        North York
# 29                0        M4Y  Downtown Toronto
# ..              ...        ...               ...
# 73                0        M5V  Downtown Toronto
# 74                1        M9L        North York
# 75                3        M4G         East York
# 76                3        M1L       Scarborough
# 77                3        M4E      East Toronto
# 78                0        M5S  Downtown Toronto
# 79                3        M4J         East York
# 80                1        M6N              York
# 81                0        M5H  Downtown Toronto
# 82                2        M1V       Scarborough
# 83                0        M6R      West Toronto
# 84                1        M3L        North York
# 85                1        M9N              York
# 86                0        M4V   Central Toronto
# 87                4        M6A        North York
# 88                1        M8V         Etobicoke
# 89                1        M9C         Etobicoke
# 90                1        M7R       Mississauga
# 91                0        M7A  Downtown Toronto
# 92                1        M9R         Etobicoke
# 93                1        M9P         Etobicoke
# 94                1        M6L        North York
# 95                0        M4T   Central Toronto
# 96                4        M3K        North York
# 97                2        M1K       Scarborough
# 98                2        M1P       Scarborough
# 99                4        M6B        North York
# 100               3        M4H         East York
# 101               2        M1E       Scarborough
# 102               1        M6M              York
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                Alderwood,Long Branch  43.602414 -79.543484
# 1                      Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 2                       Northwood Park,York University  43.767980 -79.487262
# 3                                     Woodbine Heights  43.695344 -79.318389
# 4                                  Downsview Northwest  43.761631 -79.520999
# 5                          The Danforth West,Riverdale  43.679557 -79.352188
# 6                First Canadian Place,Underground city  43.648429 -79.382280
# 7                                     Victoria Village  43.725882 -79.315572
# 8                                      York Mills West  43.752758 -79.400049
# 9      Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 10                              Newtonbrook,Willowdale  43.789053 -79.408493
# 11                                        Harbourfront  43.654260 -79.360636
# 12                                 Caledonia-Fairbanks  43.689026 -79.453512
# 13                                     L'Amoreaux West  43.799525 -79.318389
# 14                                           Agincourt  43.794200 -79.262029
# 15                                       Lawrence Park  43.728020 -79.388790
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17                                     Don Mills North  43.745906 -79.352188
# 18                             Little Portugal,Trinity  43.647927 -79.419750
# 19                Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 20   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 21                                      St. James Town  43.651494 -79.375418
# 22                    Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 23                                         Upper Rouge  43.836125 -79.205636
# 24                             Ryerson,Garden District  43.657162 -79.378937
# 25               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 26         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 27          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                                Church and Wellesley  43.665860 -79.383160
# ..                                                 ...        ...        ...
# 73   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 74                                       Humber Summit  43.756303 -79.565963
# 75                                             Leaside  43.709060 -79.363452
# 76                       Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 77                                         The Beaches  43.676357 -79.293031
# 78                       Harbord,University of Toronto  43.662696 -79.400049
# 79                                        East Toronto  43.685347 -79.338106
# 80                        The Junction North,Runnymede  43.673185 -79.487262
# 81                              Adelaide,King,Richmond  43.650571 -79.384568
# 82   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                      Downsview West  43.739015 -79.506944
# 85                                              Weston  43.706876 -79.518188
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 87                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 90               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 91                                        Queen's Park  43.662301 -79.389494
# 92   Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 93                                           Westmount  43.696319 -79.532242
# 94                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 95                          Moore Park,Summerhill East  43.689574 -79.383160
# 96                          CFB Toronto,Downsview East  43.737473 -79.464763
# 97           East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 98   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 99                                           Glencairn  43.709577 -79.445073
# 100                                   Thorncliffe Park  43.705369 -79.349372
# 101                    Guildwood,Morningside,West Hill  43.763573 -79.188711
# 102        Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
#
# [103 rows x 6 columns]

# %% [markdown]
# ## Creating the map

# %%
map_clust = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood, cluster in zip(Toronto_df['Latitude'], Toronto_df['Longitude'], Toronto_df['Neighbourhood'], Toronto_df['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clust)
       
map_clust
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
