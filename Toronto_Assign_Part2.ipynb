# %% [markdown]
# # Part 1:

# %% [markdown]
# ## 1- Importing the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2- Reading the HTML table from the Wikipedia website to a pandas dataframe

# %%
url_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
column_names = ['PostalCode', 'Borough', 'Neighborhood'] 

# Initiating the dataframe
postal_code_df = pd.DataFrame(columns=column_names)

# Reading the HTML table from wikipedia website
postal_data = pd.read_html(url_wiki)

# %% [markdown]
# ## 3- Creating the dataframe

# %%
# Ignoring the rows with "Not assigned" values
postal_data[0]=postal_data[0][~postal_data[0]['Borough'].isin(['Not assigned'])]
postal_code_df = postal_data[0]

#Grouping the dataframe according to the instructions
postal_code_df = postal_code_df.groupby(['Postcode', 'Borough'], sort=False).agg( ','.join)
postal_code_df = postal_code_df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(list)
postal_code_df = postal_code_df.sample(frac=1).reset_index()
postal_code_df['Neighbourhood']= postal_code_df['Neighbourhood'].str.join(', ')
postal_code_df
# Out:
#     Postcode           Borough  \
# 0        M7Y      East Toronto
# 1        M4T   Central Toronto
# 2        M1E       Scarborough
# 3        M1N       Scarborough
# 4        M9L        North York
# 5        M3M        North York
# 6        M9V         Etobicoke
# 7        M1K       Scarborough
# 8        M9M        North York
# 9        M3A        North York
# 10       M2K        North York
# 11       M8V         Etobicoke
# 12       M3H        North York
# 13       M5R   Central Toronto
# 14       M8X         Etobicoke
# 15       M2L        North York
# 16       M2P        North York
# 17       M4K      East Toronto
# 18       M4N   Central Toronto
# 19       M5P   Central Toronto
# 20       M5K  Downtown Toronto
# 21       M5H  Downtown Toronto
# 22       M5G  Downtown Toronto
# 23       M4H         East York
# 24       M2M        North York
# 25       M5V  Downtown Toronto
# 26       M6R      West Toronto
# 27       M4Y  Downtown Toronto
# 28       M1R       Scarborough
# 29       M9A         Etobicoke
# ..       ...               ...
# 73       M5L  Downtown Toronto
# 74       M5C  Downtown Toronto
# 75       M4W  Downtown Toronto
# 76       M5S  Downtown Toronto
# 77       M4G         East York
# 78       M1P       Scarborough
# 79       M4R   Central Toronto
# 80       M4A        North York
# 81       M5N   Central Toronto
# 82       M1T       Scarborough
# 83       M4E      East Toronto
# 84       M4S   Central Toronto
# 85       M2H        North York
# 86       M9C         Etobicoke
# 87       M2J        North York
# 88       M8W         Etobicoke
# 89       M1C       Scarborough
# 90       M3K        North York
# 91       M6L        North York
# 92       M5E  Downtown Toronto
# 93       M7A  Downtown Toronto
# 94       M6K      West Toronto
# 95       M2N        North York
# 96       M1S       Scarborough
# 97       M5A  Downtown Toronto
# 98       M4M      East Toronto
# 99       M8Y         Etobicoke
# 100      M4B         East York
# 101      M1W       Scarborough
# 102      M1M       Scarborough
#
#                                          Neighbourhood
# 0    Business Reply Mail Processing Centre 969 Eastern
# 1                           Moore Park,Summerhill East
# 2                      Guildwood,Morningside,West Hill
# 3                           Birch Cliff,Cliffside West
# 4                                        Humber Summit
# 5                                    Downsview Central
# 6    Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 7            East Birchmount Park,Ionview,Kennedy Park
# 8                                      Emery,Humberlea
# 9                                            Parkwoods
# 10                                     Bayview Village
# 11          Humber Bay Shores,Mimico South,New Toronto
# 12       Bathurst Manor,Downsview North,Wilson Heights
# 13                   The Annex,North Midtown,Yorkville
# 14         The Kingsway,Montgomery Road,Old Mill North
# 15                             Silver Hills,York Mills
# 16                                     York Mills West
# 17                         The Danforth West,Riverdale
# 18                                       Lawrence Park
# 19                  Forest Hill North,Forest Hill West
# 20             Design Exchange,Toronto Dominion Centre
# 21                              Adelaide,King,Richmond
# 22                                  Central Bay Street
# 23                                    Thorncliffe Park
# 24                              Newtonbrook,Willowdale
# 25   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 26                               Parkdale,Roncesvalles
# 27                                Church and Wellesley
# 28                                    Maryvale,Wexford
# 29                                    Islington Avenue
# ..                                                 ...
# 73                       Commerce Court,Victoria Hotel
# 74                                      St. James Town
# 75                                            Rosedale
# 76                       Harbord,University of Toronto
# 77                                             Leaside
# 78   Dorset Park,Scarborough Town Centre,Wexford He...
# 79                                  North Toronto West
# 80                                    Victoria Village
# 81                                            Roselawn
# 82               Clarks Corners,Sullivan,Tam O'Shanter
# 83                                         The Beaches
# 84                                          Davisville
# 85                                   Hillcrest Village
# 86   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 87                          Fairview,Henry Farm,Oriole
# 88                               Alderwood,Long Branch
# 89                Highland Creek,Rouge Hill,Port Union
# 90                          CFB Toronto,Downsview East
# 91                    Downsview,North Park,Upwood Park
# 92                                         Berczy Park
# 93                                        Queen's Park
# 94          Brockton,Exhibition Place,Parkdale Village
# 95                                    Willowdale South
# 96                                           Agincourt
# 97                                        Harbourfront
# 98                                     Studio District
# 99   Humber Bay,King's Mill Park,Kingsway Park Sout...
# 100                     Woodbine Gardens,Parkview Hill
# 101                                    L'Amoreaux West
# 102      Cliffcrest,Cliffside,Scarborough Village West
#
# [103 rows x 3 columns]

# %% [markdown]
# ## 4- printing the size of the dataframe

# %%
postal_code_df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2:

# %% [markdown]
# ## 5- Reading the Geospatial data csv file:

# %%
postal_new_df = pd.read_csv('http://cocl.us/Geospatial_data')
postal_new_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
postal_new_df.head()
postal_new_df['Postal Code']
#df1 = df[df['Position'].str.contains("PG")

(postal_new_df[postal_new_df['Postal Code'].str.match('M2K')]['Latitude'])
#postal_new_df[postal_new_df['Postal Code'].str.contains('M2K')]['Longitude']
#postal_new_df[['Postal Code']='M2K']['Latitude']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-228-9358cacf4256> in <module>
#       3 #df1 = df[df['Position'].str.contains("PG")
#       4
# ----> 5 (postal_new_df[postal_new_df['Postal Code'].str.match('M2K')]['Latitude']).extract(r'([\d]+)',expand=False)
#       6 #postal_new_df[postal_new_df['Postal Code'].str.contains('M2K')]['Longitude']
#       7 #postal_new_df[['Postal Code']='M2K']['Latitude']
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'extract'

# %% [markdown]
# ## 6- Creating the new dataframe

# %%
column_names = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
Toronto_df = pd.DataFrame(columns=column_names)

# %%
Toronto_df
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
Toronto_df=pd.merge(postal_code_df,postal_new_df,left_on='Postcode',right_on='Postal Code', left_index=False, right_index=False)
Toronto_df.drop('Postal Code', axis =1, inplace=True)
Toronto_df.rename(columns = {'Postcode':'PostalCode'}, inplace = True)

# %%
Toronto_df
# Out:
#     PostalCode           Borough  \
# 0          M7Y      East Toronto
# 1          M4T   Central Toronto
# 2          M1E       Scarborough
# 3          M1N       Scarborough
# 4          M9L        North York
# 5          M3M        North York
# 6          M9V         Etobicoke
# 7          M1K       Scarborough
# 8          M9M        North York
# 9          M3A        North York
# 10         M2K        North York
# 11         M8V         Etobicoke
# 12         M3H        North York
# 13         M5R   Central Toronto
# 14         M8X         Etobicoke
# 15         M2L        North York
# 16         M2P        North York
# 17         M4K      East Toronto
# 18         M4N   Central Toronto
# 19         M5P   Central Toronto
# 20         M5K  Downtown Toronto
# 21         M5H  Downtown Toronto
# 22         M5G  Downtown Toronto
# 23         M4H         East York
# 24         M2M        North York
# 25         M5V  Downtown Toronto
# 26         M6R      West Toronto
# 27         M4Y  Downtown Toronto
# 28         M1R       Scarborough
# 29         M9A         Etobicoke
# ..         ...               ...
# 73         M5L  Downtown Toronto
# 74         M5C  Downtown Toronto
# 75         M4W  Downtown Toronto
# 76         M5S  Downtown Toronto
# 77         M4G         East York
# 78         M1P       Scarborough
# 79         M4R   Central Toronto
# 80         M4A        North York
# 81         M5N   Central Toronto
# 82         M1T       Scarborough
# 83         M4E      East Toronto
# 84         M4S   Central Toronto
# 85         M2H        North York
# 86         M9C         Etobicoke
# 87         M2J        North York
# 88         M8W         Etobicoke
# 89         M1C       Scarborough
# 90         M3K        North York
# 91         M6L        North York
# 92         M5E  Downtown Toronto
# 93         M7A  Downtown Toronto
# 94         M6K      West Toronto
# 95         M2N        North York
# 96         M1S       Scarborough
# 97         M5A  Downtown Toronto
# 98         M4M      East Toronto
# 99         M8Y         Etobicoke
# 100        M4B         East York
# 101        M1W       Scarborough
# 102        M1M       Scarborough
#
#                                          Neighbourhood   Latitude  Longitude
# 0    Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 1                           Moore Park,Summerhill East  43.689574 -79.383160
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 4                                        Humber Summit  43.756303 -79.565963
# 5                                    Downsview Central  43.728496 -79.495697
# 6    Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 7            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 8                                      Emery,Humberlea  43.724766 -79.532242
# 9                                            Parkwoods  43.753259 -79.329656
# 10                                     Bayview Village  43.786947 -79.385975
# 11          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 12       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 13                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 14         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 15                             Silver Hills,York Mills  43.757490 -79.374714
# 16                                     York Mills West  43.752758 -79.400049
# 17                         The Danforth West,Riverdale  43.679557 -79.352188
# 18                                       Lawrence Park  43.728020 -79.388790
# 19                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 20             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 21                              Adelaide,King,Richmond  43.650571 -79.384568
# 22                                  Central Bay Street  43.657952 -79.387383
# 23                                    Thorncliffe Park  43.705369 -79.349372
# 24                              Newtonbrook,Willowdale  43.789053 -79.408493
# 25   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 26                               Parkdale,Roncesvalles  43.648960 -79.456325
# 27                                Church and Wellesley  43.665860 -79.383160
# 28                                    Maryvale,Wexford  43.750072 -79.295849
# 29                                    Islington Avenue  43.667856 -79.532242
# ..                                                 ...        ...        ...
# 73                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 74                                      St. James Town  43.651494 -79.375418
# 75                                            Rosedale  43.679563 -79.377529
# 76                       Harbord,University of Toronto  43.662696 -79.400049
# 77                                             Leaside  43.709060 -79.363452
# 78   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 79                                  North Toronto West  43.715383 -79.405678
# 80                                    Victoria Village  43.725882 -79.315572
# 81                                            Roselawn  43.711695 -79.416936
# 82               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 83                                         The Beaches  43.676357 -79.293031
# 84                                          Davisville  43.704324 -79.388790
# 85                                   Hillcrest Village  43.803762 -79.363452
# 86   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 87                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 88                               Alderwood,Long Branch  43.602414 -79.543484
# 89                Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 90                          CFB Toronto,Downsview East  43.737473 -79.464763
# 91                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 92                                         Berczy Park  43.644771 -79.373306
# 93                                        Queen's Park  43.662301 -79.389494
# 94          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 95                                    Willowdale South  43.770120 -79.408493
# 96                                           Agincourt  43.794200 -79.262029
# 97                                        Harbourfront  43.654260 -79.360636
# 98                                     Studio District  43.659526 -79.340923
# 99   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 100                     Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 101                                    L'Amoreaux West  43.799525 -79.318389
# 102      Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
#
# [103 rows x 5 columns]
